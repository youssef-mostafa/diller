# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

# %%
# download url data from internet
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(url).text
Canada_data = BeautifulSoup(source, 'lxml')

# %%
# creat a new Dataframe
column_names = ['Postalcode','Borough','Neighborhood']
toronto = pd.DataFrame(columns = column_names)

# %%
content = Canada_data.find('div', class_='mw-parser-output')
table = content.table.tbody
postcode = 0
borough = 0
neighborhood = 0

for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
    toronto = toronto.append({'Postalcode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# clean dataframe 
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1
                                 
df = toronto.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head()
# Out:
#   Postalcode         Borough  \
# 0      M1A\n  Not assigned\n
# 1      M1B\n   Scarborough\n
# 2      M1C\n   Scarborough\n
# 3      M1E\n   Scarborough\n
# 4      M1G\n   Scarborough\n
#
#                                         Neighborhood
# 0                                       , , , \n, ,
# 1  Malvern / Rouge, Malvern / Rouge, Malvern / Ro...
# 2  Rouge Hill / Port Union / Highland Creek, Roug...
# 3  Guildwood / Morningside / West Hill, Guildwood...
# 4   Woburn, Woburn, Woburn, Woburn\n, Woburn, Woburn

# %%
df = df.dropna()
empty = 'Not assigned'
df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)
# Out:
#   File "<ipython-input-18-c13d92e268cf>", line 3
#     df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)
#                                                                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
df.head()
# Out:
#   Postalcode         Borough  \
# 0      M1A\n  Not assigned\n
# 1      M1B\n   Scarborough\n
# 2      M1C\n   Scarborough\n
# 3      M1E\n   Scarborough\n
# 4      M1G\n   Scarborough\n
#
#                                         Neighborhood
# 0                                       , , , \n, ,
# 1  Malvern / Rouge, Malvern / Rouge, Malvern / Ro...
# 2  Rouge Hill / Port Union / Highland Creek, Roug...
# 3  Guildwood / Morningside / West Hill, Guildwood...
# 4   Woburn, Woburn, Woburn, Woburn\n, Woburn, Woburn

# %%
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')

# %%
print(df2.shape)
df2.head(10)
# Out:
# (180, 3)
#   Postalcode         Borough  \
# 0      M1A\n  Not assigned\n
# 1      M1B\n   Scarborough\n
# 2      M1C\n   Scarborough\n
# 3      M1E\n   Scarborough\n
# 4      M1G\n   Scarborough\n
# 5      M1H\n   Scarborough\n
# 6      M1J\n   Scarborough\n
# 7      M1K\n   Scarborough\n
# 8      M1L\n   Scarborough\n
# 9      M1M\n   Scarborough\n
#
#                                         Neighborhood
# 0                                       , , , \n, ,
# 1  Malvern / Rouge, Malvern / Rouge, Malvern / Ro...
# 2  Rouge Hill / Port Union / Highland Creek, Roug...
# 3  Guildwood / Morningside / West Hill, Guildwood...
# 4   Woburn, Woburn, Woburn, Woburn\n, Woburn, Woburn
# 5  Cedarbrae, Cedarbrae, Cedarbrae, Cedarbrae\n, ...
# 6  Scarborough Village, Scarborough Village, Scar...
# 7  Kennedy Park / Ionview / East Birchmount Park,...
# 8  Golden Mile / Clairlea / Oakridge, Golden Mile...
# 9  Cliffside / Cliffcrest / Scarborough Village W...
